# %% [markdown]
# ### Decision Tree for classification

# %%
from sklearn.datasets import load_iris
from sklearn import tree
from graphviz import Source

# %%
iris = load_iris()

# %%
X = iris.data[:,2:]
y = iris.target

# %%
tree_clf = tree.DecisionTreeClassifier(criterion = 'entropy', max_depth = 2)
tree_clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2)

# %%
tree.export_graphviz(
    tree_clf,
    out_file = 'iris_tree.dot',
    feature_names = iris.feature_names[2:],
    class_names = iris.target_names,
    rounded = True,
    filled = True
)
with open ("iris_tree.dot") as f:
    dot_graph = f.read()

Source(dot_graph)

# %% [markdown]
# ### Decision Tree for Regression

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()

# %%
X = diabetes.data
y = diabetes.target

# %%
tree_reg = tree.DecisionTreeRegressor(criterion = 'squared_error', max_depth = 3)
tree_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
tree.export_graphviz(
    tree_reg,
    out_file = 'diabetes_tree.dot',
    feature_names = diabetes.feature_names,
    class_names = diabetes.target,
    rounded = True,
    filled = True
)
with open ("diabetes_tree.dot") as f:
    dot_graph = f.read()

Source(dot_graph)
