# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('toy_dataset.csv')

# %%
df.head()
# Out:
#    Number    City Gender  Age   Income Illness
# 0       1  Dallas   Male   41  40367.0      No
# 1       2  Dallas   Male   54  45084.0      No
# 2       3  Dallas   Male   42  52483.0      No
# 3       4  Dallas   Male   40  40941.0      No
# 4       5  Dallas   Male   46  50289.0      No

# %%
crosstab_df = pd.crosstab(df.City, df.Gender)
crosstab_df
# Out:
# Gender           Female   Male
# City
# Austin             5385   6907
# Boston             3715   4586
# Dallas             8705  11002
# Los Angeles       14285  17888
# Mountain View      6276   7943
# New York City     22172  28135
# San Diego          2098   2783
# Washington D.C.    3564   4556

# %%
male_age = df.Age[df.Gender == 'Male']

# %%
male_age
# Out:
# 0         41
# 1         54
# 2         42
# 3         40
# 4         46
#           ..
# 149993    64
# 149995    48
# 149996    25
# 149997    26
# 149998    25
# Name: Age, Length: 83800, dtype: int64

# %%
male_age_mean = np.mean(df.Age[df.Gender == 'Male'])
female_age_mean = np.mean(df.Age[df.Gender == 'Female'])

# %%
mean_diff = male_age_mean - female_age_mean

# %%
mean_diff
# Out:
# -0.08513905212382156

# %%
sns.boxplot(data = df, x = df['City'], y = df['Income'])
plt.figure(figsize = (20,16))
plt.show()

# %%
df.Age.corr(df.Income)
# Out:
# -0.0013181143630648109

# %%
sns.scatterplot(data = df, x = df.Income, y = df.Age)
#data is no pattern because corr doesnot have a relation
# Out:
# <Axes: xlabel='Income', ylabel='Age'>
